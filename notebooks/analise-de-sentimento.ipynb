# %%
pip install googletrans==3.1.0a0
# Out:
# ...
#      |████████████████████████████████| 55 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 10.6 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 65 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.0 MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=691cdcd0c7733b530c278400c5db03553730cbcb60e22254657b1777085f74fb
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# ...

# %%
from textblob import TextBlob
from googletrans import Translator

# %%
frase = 'Python é ótimo para Machine Learning'
tb = TextBlob(frase)
#tb_en = tb.translate(to='en') - irei modificar pq no dia do estudo estamos com problema na API https://github.com/sloria/TextBlob/issues/395
translator = Translator()
frase_en = translator.translate(frase, dest='en')
tb_en = TextBlob(frase_en.text)

# %%
tb_en.sentiment.polarity
# Out:
# 0.8
